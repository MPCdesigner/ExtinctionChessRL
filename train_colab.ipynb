# %% [markdown]
# # Extinction Chess RL Training
# 1. Upload project files
# 2. Run training
# 3. Download checkpoint

# %%
# Step 1: Upload project files
# Run this cell, then upload the zip when prompted
from google.colab import files
uploaded = files.upload()  # upload extinction_chess_rl.zip

# %%
# Step 2: Unzip and setup
import os
# !unzip -o extinction_chess_rl.zip -d /content/extinction-chess

# Find the src directory
for root, dirs, fls in os.walk('/content/extinction-chess'):
    if 'src' in dirs and 'train.py' in fls:
        PROJECT_DIR = root
        break
else:
    # Maybe files are directly in extinction-chess/
    PROJECT_DIR = '/content/extinction-chess'

print(f'Project dir: {PROJECT_DIR}')
os.chdir(PROJECT_DIR)
# !ls

# %%
# Step 3: Check GPU
import torch
print(f'PyTorch: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %%
# Step 4: Train WITHOUT MCTS (faster, good baseline)
# !python train.py --iterations 100 --games 200 --no-resume

# %%
# Step 5 (optional): Train WITH MCTS (slower but stronger)
# Only run this AFTER step 4, so it resumes from the baseline
# !python train.py --mcts --iterations 50 --games 60 --simulations 100

# %%
# Step 6: Download the trained checkpoint
from google.colab import files
files.download('models/cnn_latest.pt')
files.download('models/cnn_best.pt')
